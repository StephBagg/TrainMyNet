# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
x_data =  np.linspace(0,10,num=1000)
A_data = 47.0
b_data = -10.0

y_data = A_data*x_data + b_data
y_data += np.random.normal(scale=50.0,size=y_data.size)

# %%
plt.scatter(x_data,y_data)
plt.show()

# %%
X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)
A = tf.Variable(0,dtype=tf.float32)
b = tf.Variable(0,dtype=tf.float32)


y_pred = A*X + b

loss = tf.norm(Y-y_pred)

loss_sum = tf.summary.scalar('Loss',loss)

opt = tf.train.GradientDescentOptimizer(0.001)
train_op = opt.minimize(loss)

# %%
sess = tf.Session(graph=graph)
init = tf.global_variables_initializer()
sess.run(init)
for i in range(10000):
    x_d = np.random.choice(x_data,size=[100])
    y_d = A_data*x_d + b_data
    feed_dict = {X:x_d,Y:y_d}
    _,loss_,A_,b_ = sess.run([train_op,loss,A,b],feed_dict=feed_dict)
    #print("Loss {}".format(loss_))
    if i%1000 == 0:
        Y_plot = A_*x_data + b_
        plt.figure(1)
        plt.clf()
        plt.scatter(x_data,y_data)
        plt.plot(x_data,Y_plot,'r-')
        plt.show()
        
print(A_,b_)
# Out:
# 46.995987 -10.000965
